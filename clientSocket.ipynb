# %% [markdown]
# <a href="https://colab.research.google.com/github/ytg000629/Building_Safety_Indicator/blob/main/clientSocket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Client

# %%
import socket

# Create a client socket
clientSocket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

# Connect to the server
host = '127.0.0.1'
port = 12250
clientSocket.connect((host, port))

# Receive data from server
a = []
while True:
    dataFromServer = clientSocket.recv(1024).decode('utf-8', 'ignore')
    if dataFromServer == 'bye':
        print(dataFromServer)
        break
    a.append(dataFromServer)
    print(dataFromServer)

# Close the client socket
clientSocket.close()
# Out:
# ﻿현장안전센터거리,시간단위기온,시간단위풍속,시간단위가시거리,재산피해액,실효습도,전기사용량(KWh),가스사용량(KWh),인명피해확률,화재발생시각_새벽,화재발생시각_저녁,화재발생시각_주간
#
# 3,0.2,2.2,491,13391,54.27375,18096.2104633905,11774.100170177806,0.05292932571918201,1,0,0
#
# 2,9.3,1.9,703,35,49.554054,18096.2104633905,11774.100170177806,0.04056220477352409,0,0,1
#
# 1,-4.2,1.8,2000,308,31.607682,18096.2104633905,11774.100170177806,0.03003974217749943,0,1,0
#
# 1,-4.4,4.5,558,184,50.355768000000005,18096.2104633905,11774.100170177806,0.051948512437324824,0,0,1
#
# 3,1.5,5.9,634,877,43.742292000000006,18096.2104633905,11774.100170177806,0.09604585418363011,1,0,0
#
# 4,-6.1,2.6,2000,135,39.579228,18096.2104633905,11774.100170177806,0.06076779007944135,1,0,0
#
# 2,0.6,0.1,526,105,46.303062,18096.2104633905,11774.100170177806,0.4090218291127186,0,0,0
#
# 2,-0.1,4.2,1975,422,38.257452,18096.2104633905,11774.100170177806,0.0568056738788165,0,0,1
#
# 1,-7.5,0.4,1965,7315,41.605767,18096.2104633905,11774.100170177806,0.031233721624443093,0,0,1
#
# ...
